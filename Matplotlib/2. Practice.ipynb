# %% [markdown]
# # Practice

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Histograms

# %%
blood_sugar_men = [113,85,90,150,149,88,93,115,134,80,77,38,130]
blood_sugar_women = [45,63,120,35,43,88,79,66,130,111,76,44,90,80]

plt.hist([blood_sugar_men, blood_sugar_women],
         bins = [80,100,125,150], rwidth = 0.95, color =
         ['green','orange'], label = ['men','women'])
plt.show()
